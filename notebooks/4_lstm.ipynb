# %% [markdown]
# ### Import, mount, and configure

# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn
import sklearn
import statsmodels
import tensorflow as tf
import tqdm
from google.colab import drive

# %%
drive.mount('/content/drive')

DRIVE_ROOT = Path('/content/drive/MyDrive')

PROJECT_ROOT = DRIVE_ROOT / 'projects/btc'
PROJECT_DATA_DIR = PROJECT_ROOT / 'data'
PROJECT_CLEANED_DIR = PROJECT_DATA_DIR / 'cleaned'

BTC_CLEANED_CSV_FILENAME = 'btc_274_cleaned.csv'

BTC_CLEANED_FILEPATH = PROJECT_CLEANED_DIR / BTC_CLEANED_CSV_FILENAME
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
if 'google.colab' in sys.modules:
    # %pip install -q -U keras_tuner

import keras_tuner as kt

# %%
# %pip install finta
# Out:
# Requirement already satisfied: finta in /usr/local/lib/python3.12/dist-packages (1.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from finta) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from finta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->finta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->finta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->finta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->finta) (1.17.0)

# %%
project_root = os.path.abspath(PROJECT_ROOT)

if project_root not in sys.path:
  sys.path.append(project_root)

print(f'Project root "{project_root}" added to sys.path.')
# Out:
# Project root "/content/drive/MyDrive/projects/btc" added to sys.path.

# %%
from src.analysis import *
from src.data_loader import *
from src.data_splitter import *
from src.model import *
from src.preprocessing import *
from src.utils import *
from src.visualization import *

# %% [markdown]
# ### Load the cleaned dataset, and resample it

# %%
# A missing date(2025-03-15) exists in the test dataset.
X_btc_cleaned = load_btc_dataset(BTC_CLEANED_FILEPATH, 'date', True)
btc_resampled = resample_btc_data(X_btc_cleaned)
# Out:
# Loading dataset from: btc_274_cleaned.csv...
# Dataset loaded successfully.
#
# --- Resampling BTC Data to Multiple Timeframes ---
# Resampling to hourly frequency...
# Resampling to daily frequency...
# Resampling to weekly frequency...
# Resampling to monthly frequency...
# --- BTC Data Resampling Complete ---

# %% [markdown]
# ### Split the resampled datasets into a training set, a validation set, and a test set of respective timeframe, and take returns

# %%
for X_btc_resampled in btc_resampled.values():
    X_btc_resampled = calculate_returns(X_btc_resampled, 'close')

# %%
X_btc_daily_train, X_btc_daily_valid, X_btc_daily_test = split_btc_dataset(btc_resampled['daily'], 'Day')
X_btc_weekly_train, X_btc_weekly_valid, X_btc_weekly_test = split_btc_dataset(btc_resampled['weekly'], 'Week')
# Out:
# --- Splitting BTC Dataset to Training, Validation, and Test Set (Day) ---
# --- BTC Dataset Splitting Complete ---
#
# --- Splitting BTC Dataset to Training, Validation, and Test Set (Week) ---
# --- BTC Dataset Splitting Complete ---

# %% [markdown]
# ### Run the ADF test on datasets at multiple frequencies to verify stationarity and seasonality

# %%
run_adf_test(X_btc_daily_train, 'returns_close', 'BTC Daily Closing Returns')
run_adf_test(X_btc_weekly_train, 'returns_close', 'BTC Weekly Closing Returns')
# Out:
# =======================================
# = ADF Test: BTC Daily Closing Returns =
# =======================================
# ADF Statistics: -10.1710
# p-value: 0.0000
# Critical Values:
# 	1%:-3.4320
# 	5%:-2.8623
# 	10%:-2.5672
# Conclusion: The p-value is less than or equal to 0.05. The data is likely stationary and seasonal.
#
# ========================================
# = ADF Test: BTC Weekly Closing Returns =
# ========================================
# ADF Statistics: -11.0168
# p-value: 0.0000
# Critical Values:
# 	1%:-3.4421
# 	5%:-2.8667
# 	10%:-2.5695
# Conclusion: The p-value is less than or equal to 0.05. The data is likely stationary and seasonal.

# %% [markdown]
# ### Fine-tune hyperparameters and utilize techniques.
# 1.   Architectural Hyperparameters
#   *   Number of hidden layers (Conv1D and RNN)
#       * Deep networks have a much higher parameter efficiency than shallow ones.
#   *   Number of neurons per RNN layer
#       * It's generally more effective to add more layers than to increase the number of neurons to improve performance.
#   *   Number of filters per Conv1D layer
#   *   Kernel size (Conv1D)
#   *   Stride (Conv1D)
#   *   Padding (Conv1D)
#   *   Type of RNN cell (LSTM/GRU)
#   *   Activation function (Conv1D, RNN and Dense)
#       * A poor choice of activation functions potentially creates unstable gradients.
#
# 2.   Training & Optimization Hyperparameters
#   *   Type of optimizer (e.g., Adam, Nadam, etc.)
#       * A faster optimizer can hugely boost traning speed.
#   *   Learning rate
#       * The most important hyperparameter. The optimal learning rate is generally about half of the maximum learning rate (i.e., the learning rate above which the training algorithm diverges .).
#   *   Batch size
#       * Batch size can have a significant impact on a model's performance and training time.
#
# 3.   Optimization & Regularization Techniques
#   *   Kernel Initialization (e.g., Glorot/He)
#   *   Normalization (Layer normalization)
#       * Batch normalization cannot be used as efficiently with RNNs as with deep feedforward networks.
#       * Layer normalization can prevent unstable gradients during training.
#   *   Learning Rate Scheduling (e.g., ReduceLROnPlateau)
#   *   Gradient Clipping
#       * Gradient clipping mitigates the exploding gradients by clipping the gradients during backpropagation.
#   *   L1/L2 Regularization
#   *   Dropout (Recurrent Dropout for RNN)
#   *   Early Stopping (to prevent overfitting and save time)

# %% [markdown]
# ### LSTM Model Evaluation and Final Forecast (1-Month)

# %%
tf.random.set_seed(42)

# %%
FEATURE_COLS = ['open', 'high', 'low', 'close', 'volume']
TARGET_COL = 'close'
INPUT_WINDOW = 270
TARGET_WINDOW = 30
FORECAST_HORIZON = 30

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_daily_valid, 'close', 30, 'Days', 'Validation')
# Out:
# ===============================================================
# = Naive Model Evaluation on Validation Set (Horizon: 30 Days) =
# ===============================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 10.5643%
# - Directional Accuracy (DA): 54.8611%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2024-03-15: $51475.00

# %%
lstm_metrics, lstm_pred = run_lstm_model(X_btc_daily_train, X_btc_daily_valid, X_btc_daily_test,
                                         FEATURE_COLS, TARGET_COL, FORECAST_HORIZON,
                                         INPUT_WINDOW, TARGET_WINDOW,
                                         'Days', 'Validation',
                                         naive_metrics, 'direct')
# Out:
# Trial 15 Complete [00h 01m 12s]
# val_mae: 0.3603381812572479
#
# Best val_mae So Far: 0.36025407910346985
# Total elapsed time: 05h 01m 02s
#
# LSTM hyperparameter tuning complete:
# - n_conv_layers: 2
# - kernel_size: 5
# - n_rnn_layers: 1
# - use_l2: True
# - dropout_rate: 0.0
# - learning_rate: 0.005218086982564764
# - optimizer: nadam
# - clipnorm: 0.8
# - filters_0: 192
# - units_0: 192
# - filters_1: 64
# - units_1: 224
# - filters_2: 96
# - units_2: 32
# - l2_rate: 0.0025124079357885637
#
# --- Fitting LSTM Model ---
# Epoch 1/100
# 113/113 - 5s - 46ms/step - loss: 0.7517 - mae: 0.6574 - val_loss: 0.1596 - val_mae: 0.3612 - learning_rate: 0.0052
# Epoch 2/100
# 113/113 - 2s - 18ms/step - loss: 0.3390 - mae: 0.6298 - val_loss: 0.1333 - val_mae: 0.3607 - learning_rate: 0.0052
# Epoch 3/100
# 113/113 - 2s - 18ms/step - loss: 0.3328 - mae: 0.6297 - val_loss: 0.1339 - val_mae: 0.3622 - learning_rate: 0.0052
# Epoch 4/100
# 113/113 - 2s - 18ms/step - loss: 0.3321 - mae: 0.6285 - val_loss: 0.1348 - val_mae: 0.3644 - learning_rate: 0.0052
# Epoch 5/100
# 113/113 - 2s - 18ms/step - loss: 0.3327 - mae: 0.6300 - val_loss: 0.1346 - val_mae: 0.3640 - learning_rate: 0.0052
# Epoch 6/100
# 113/113 - 2s - 18ms/step - loss: 0.3324 - mae: 0.6285 - val_loss: 0.1347 - val_mae: 0.3693 - learning_rate: 0.0052
# Epoch 7/100
# 113/113 - 2s - 18ms/step - loss: 0.3326 - mae: 0.6301 - val_loss: 0.1329 - val_mae: 0.3610 - learning_rate: 0.0052
# Epoch 8/100
# 113/113 - 2s - 18ms/step - loss: 0.3324 - mae: 0.6285 - val_loss: 0.1329 - val_mae: 0.3604 - learning_rate: 0.0052
# Epoch 9/100
# 113/113 - 2s - 18ms/step - loss: 0.3320 - mae: 0.6281 - val_loss: 0.1329 - val_mae: 0.3604 - learning_rate: 0.0052
# Epoch 10/100
# 113/113 - 2s - 18ms/step - loss: 0.3319 - mae: 0.6280 - val_loss: 0.1329 - val_mae: 0.3603 - learning_rate: 0.0052
# Epoch 11/100
# 113/113 - 2s - 18ms/step - loss: 0.3319 - mae: 0.6281 - val_loss: 0.1329 - val_mae: 0.3608 - learning_rate: 0.0052
# Epoch 12/100
# 113/113 - 2s - 18ms/step - loss: 0.3323 - mae: 0.6285 - val_loss: 0.1329 - val_mae: 0.3603 - learning_rate: 0.0052
# Epoch 13/100
# 113/113 - 2s - 18ms/step - loss: 0.3322 - mae: 0.6283 - val_loss: 0.1328 - val_mae: 0.3604 - learning_rate: 0.0052
# Epoch 14/100
# 113/113 - 2s - 18ms/step - loss: 0.3317 - mae: 0.6277 - val_loss: 0.1332 - val_mae: 0.3630 - learning_rate: 0.0052
# Epoch 15/100
# 113/113 - 2s - 18ms/step - loss: 0.3320 - mae: 0.6279 - val_loss: 0.1341 - val_mae: 0.3627 - learning_rate: 0.0052
# Epoch 16/100
# 113/113 - 2s - 18ms/step - loss: 0.3322 - mae: 0.6279 - val_loss: 0.1329 - val_mae: 0.3603 - learning_rate: 0.0026
# Epoch 17/100
# 113/113 - 2s - 18ms/step - loss: 0.3312 - mae: 0.6268 - val_loss: 0.1329 - val_mae: 0.3602 - learning_rate: 0.0026
# Epoch 18/100
# 113/113 - 2s - 18ms/step - loss: 0.3329 - mae: 0.6289 - val_loss: 0.1328 - val_mae: 0.3604 - learning_rate: 0.0026
# Epoch 19/100
# 113/113 - 2s - 18ms/step - loss: 0.3305 - mae: 0.6258 - val_loss: 0.1337 - val_mae: 0.3618 - learning_rate: 0.0026
# Epoch 20/100
# 113/113 - 2s - 18ms/step - loss: 0.3316 - mae: 0.6273 - val_loss: 0.1330 - val_mae: 0.3604 - learning_rate: 0.0026
# Epoch 21/100
# 113/113 - 2s - 18ms/step - loss: 0.3329 - mae: 0.6289 - val_loss: 0.1330 - val_mae: 0.3603 - learning_rate: 0.0026
# Epoch 22/100
# 113/113 - 2s - 18ms/step - loss: 0.3317 - mae: 0.6275 - val_loss: 0.1331 - val_mae: 0.3605 - learning_rate: 0.0026
# Epoch 23/100
# 113/113 - 2s - 18ms/step - loss: 0.3311 - mae: 0.6266 - val_loss: 0.1329 - val_mae: 0.3603 - learning_rate: 0.0026
# Epoch 24/100
# 113/113 - 2s - 18ms/step - loss: 0.3321 - mae: 0.6279 - val_loss: 0.1328 - val_mae: 0.3605 - learning_rate: 0.0026
# Epoch 25/100
# 113/113 - 2s - 18ms/step - loss: 0.3317 - mae: 0.6274 - val_loss: 0.1329 - val_mae: 0.3615 - learning_rate: 0.0013
# Epoch 26/100
# 113/113 - 2s - 18ms/step - loss: 0.3319 - mae: 0.6276 - val_loss: 0.1331 - val_mae: 0.3622 - learning_rate: 0.0013
# Epoch 27/100
# 113/113 - 2s - 18ms/step - loss: 0.3315 - mae: 0.6272 - val_loss: 0.1333 - val_mae: 0.3633 - learning_rate: 0.0013
# Epoch 28/100
# 113/113 - 2s - 18ms/step - loss: 0.3315 - mae: 0.6272 - val_loss: 0.1330 - val_mae: 0.3619 - learning_rate: 0.0013
# Epoch 29/100
# 113/113 - 2s - 18ms/step - loss: 0.3315 - mae: 0.6271 - val_loss: 0.1332 - val_mae: 0.3626 - learning_rate: 0.0013
# Epoch 30/100
# 113/113 - 2s - 18ms/step - loss: 0.3317 - mae: 0.6273 - val_loss: 0.1330 - val_mae: 0.3619 - learning_rate: 0.0013
# Epoch 31/100
# 113/113 - 2s - 18ms/step - loss: 0.3316 - mae: 0.6274 - val_loss: 0.1331 - val_mae: 0.3623 - learning_rate: 0.0013
# Epoch 32/100
# 113/113 - 2s - 18ms/step - loss: 0.3320 - mae: 0.6279 - val_loss: 0.1332 - val_mae: 0.3628 - learning_rate: 6.5226e-04
#
# --- Evaluating LSTM Model ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Day 1 | MAPE: 1.4237% | DA: 54.1667%
# Day 2 | MAPE: 1.9527% | DA: 53.6458%
# Day 3 | MAPE: 2.4435% | DA: 53.1250%
# Day 4 | MAPE: 2.8737% | DA: 53.6458%
# Day 5 | MAPE: 3.3122% | DA: 53.6458%
# Day 6 | MAPE: 3.6295% | DA: 53.6458%
# Day 7 | MAPE: 3.9874% | DA: 53.6458%
# Day 8 | MAPE: 4.2770% | DA: 53.1250%
# Day 9 | MAPE: 4.5876% | DA: 53.6458%
# Day 10 | MAPE: 4.8540% | DA: 54.1667%
# Day 11 | MAPE: 5.0946% | DA: 54.6875%
# Day 12 | MAPE: 5.3141% | DA: 54.1667%
# Day 13 | MAPE: 5.4691% | DA: 54.6875%
# Day 14 | MAPE: 5.6616% | DA: 54.6875%
# Day 15 | MAPE: 5.8786% | DA: 55.2083%
# Day 16 | MAPE: 6.2124% | DA: 55.2083%
# Day 17 | MAPE: 6.5043% | DA: 55.2083%
# Day 18 | MAPE: 6.7830% | DA: 55.2083%
# Day 19 | MAPE: 7.0936% | DA: 55.2083%
# Day 20 | MAPE: 7.4002% | DA: 55.2083%
# Day 21 | MAPE: 7.7349% | DA: 54.6875%
# Day 22 | MAPE: 8.0190% | DA: 54.6875%
# Day 23 | MAPE: 8.3524% | DA: 55.2083%
# Day 24 | MAPE: 8.6718% | DA: 55.7292%
# Day 25 | MAPE: 8.9622% | DA: 55.7292%
# Day 26 | MAPE: 9.2817% | DA: 55.7292%
# Day 27 | MAPE: 9.5830% | DA: 55.7292%
# Day 28 | MAPE: 9.8633% | DA: 56.2500%
# Day 29 | MAPE: 10.0620% | DA: 55.7292%
# Day 30 | MAPE: 10.2937% | DA: 55.7292%
# - Mean Absolute Percentage Error (MAPE): 10.2937%
# - Directional Accuracy (DA): 55.7292%
#
# --- Selecting Best LSTM Model ---
# - Naive Model Benchmark: MAPE: 10.5643%, DA: 54.8611%
#
# Found 1 candidate model(s) that beat the naive model:
# - Model: hyperparameters, MAPE: 10.2937%, DA: 55.7292%
#
# --- Best LSTM Model Chosen ---
# - MAPE: 10.2937%
# - DA: 55.7292%
#
# Fitting, evaluating, and predicting LSTM model with the best hyperparameters...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)               │ (None, None, 192)      │         4,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, None, 64)       │        61,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, None, 192)      │       197,376 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_4           │ (None, None, 192)      │           384 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, None, 30)       │         5,790 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 270,046 (1.03 MB)
#  Trainable params: 270,046 (1.03 MB)
#  Non-trainable params: 0 (0.00 B)
# --- Fitting LSTM Model ---
# --- Preparing Data for LSTM ---
# Epoch 1/100
# 128/128 - 6s - 44ms/step - loss: 0.7209 - mae: 0.6584 - val_loss: 0.1951 - val_mae: 0.4540 - learning_rate: 0.0052
# Epoch 2/100
# 128/128 - 2s - 17ms/step - loss: 0.3379 - mae: 0.6318 - val_loss: 0.1848 - val_mae: 0.4667 - learning_rate: 0.0052
# Epoch 3/100
# 128/128 - 2s - 17ms/step - loss: 0.3332 - mae: 0.6289 - val_loss: 0.1790 - val_mae: 0.4553 - learning_rate: 0.0052
# Epoch 4/100
# 128/128 - 2s - 17ms/step - loss: 0.3337 - mae: 0.6307 - val_loss: 0.1777 - val_mae: 0.4531 - learning_rate: 0.0052
# Epoch 5/100
# 128/128 - 2s - 18ms/step - loss: 0.3336 - mae: 0.6297 - val_loss: 0.1775 - val_mae: 0.4517 - learning_rate: 0.0052
# Epoch 6/100
# 128/128 - 2s - 18ms/step - loss: 0.3335 - mae: 0.6298 - val_loss: 0.1782 - val_mae: 0.4523 - learning_rate: 0.0052
# Epoch 7/100
# 128/128 - 2s - 18ms/step - loss: 0.3328 - mae: 0.6282 - val_loss: 0.1782 - val_mae: 0.4530 - learning_rate: 0.0052
# Epoch 8/100
# 128/128 - 2s - 17ms/step - loss: 0.3339 - mae: 0.6302 - val_loss: 0.1776 - val_mae: 0.4522 - learning_rate: 0.0052
# Epoch 9/100
# 128/128 - 2s - 17ms/step - loss: 0.3331 - mae: 0.6288 - val_loss: 0.1776 - val_mae: 0.4516 - learning_rate: 0.0052
# Epoch 10/100
# 128/128 - 2s - 17ms/step - loss: 0.3336 - mae: 0.6297 - val_loss: 0.1777 - val_mae: 0.4510 - learning_rate: 0.0052
# Epoch 11/100
# 128/128 - 2s - 18ms/step - loss: 0.3331 - mae: 0.6287 - val_loss: 0.1776 - val_mae: 0.4520 - learning_rate: 0.0052
# Epoch 12/100
# 128/128 - 2s - 17ms/step - loss: 0.3326 - mae: 0.6280 - val_loss: 0.1785 - val_mae: 0.4514 - learning_rate: 0.0052
# Epoch 13/100
# 128/128 - 2s - 17ms/step - loss: 0.3334 - mae: 0.6293 - val_loss: 0.1778 - val_mae: 0.4509 - learning_rate: 0.0052
# Epoch 14/100
# 128/128 - 2s - 17ms/step - loss: 0.3326 - mae: 0.6281 - val_loss: 0.1778 - val_mae: 0.4508 - learning_rate: 0.0052
# Epoch 15/100
# 128/128 - 2s - 17ms/step - loss: 0.3331 - mae: 0.6286 - val_loss: 0.1775 - val_mae: 0.4520 - learning_rate: 0.0052
# Epoch 16/100
# 128/128 - 2s - 17ms/step - loss: 0.3333 - mae: 0.6288 - val_loss: 0.1798 - val_mae: 0.4536 - learning_rate: 0.0052
# Epoch 17/100
# 128/128 - 2s - 17ms/step - loss: 0.3329 - mae: 0.6285 - val_loss: 0.1778 - val_mae: 0.4509 - learning_rate: 0.0052
# Epoch 18/100
# 128/128 - 2s - 17ms/step - loss: 0.3326 - mae: 0.6279 - val_loss: 0.1776 - val_mae: 0.4511 - learning_rate: 0.0052
# Epoch 19/100
# 128/128 - 2s - 17ms/step - loss: 0.3328 - mae: 0.6281 - val_loss: 0.1782 - val_mae: 0.4510 - learning_rate: 0.0052
# Epoch 20/100
# 128/128 - 2s - 17ms/step - loss: 0.3325 - mae: 0.6276 - val_loss: 0.1775 - val_mae: 0.4512 - learning_rate: 0.0052
# Epoch 21/100
# 128/128 - 2s - 17ms/step - loss: 0.3325 - mae: 0.6276 - val_loss: 0.1782 - val_mae: 0.4510 - learning_rate: 0.0026
# Epoch 22/100
# 128/128 - 2s - 17ms/step - loss: 0.3324 - mae: 0.6275 - val_loss: 0.1776 - val_mae: 0.4509 - learning_rate: 0.0026
# Epoch 23/100
# 128/128 - 2s - 17ms/step - loss: 0.3324 - mae: 0.6275 - val_loss: 0.1788 - val_mae: 0.4518 - learning_rate: 0.0026
# Epoch 24/100
# 128/128 - 2s - 17ms/step - loss: 0.3324 - mae: 0.6274 - val_loss: 0.1792 - val_mae: 0.4525 - learning_rate: 0.0026
# Epoch 25/100
# 128/128 - 2s - 17ms/step - loss: 0.3321 - mae: 0.6269 - val_loss: 0.1786 - val_mae: 0.4515 - learning_rate: 0.0026
# Epoch 26/100
# 128/128 - 2s - 17ms/step - loss: 0.3322 - mae: 0.6271 - val_loss: 0.1777 - val_mae: 0.4509 - learning_rate: 0.0026
# Epoch 27/100
# 128/128 - 2s - 17ms/step - loss: 0.3319 - mae: 0.6267 - val_loss: 0.1785 - val_mae: 0.4513 - learning_rate: 0.0026
# Epoch 28/100
# 128/128 - 2s - 17ms/step - loss: 0.3323 - mae: 0.6272 - val_loss: 0.1784 - val_mae: 0.4513 - learning_rate: 0.0013
# Epoch 29/100
# 128/128 - 2s - 17ms/step - loss: 0.3327 - mae: 0.6278 - val_loss: 0.1775 - val_mae: 0.4512 - learning_rate: 0.0013
#
# --- Evaluating LSTM Model ---
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Day 1 | MAPE: 1.8673% | DA: 48.7047%
# Day 2 | MAPE: 2.5102% | DA: 48.1865%
# Day 3 | MAPE: 3.0145% | DA: 48.1865%
# Day 4 | MAPE: 3.3497% | DA: 51.8135%
# Day 5 | MAPE: 3.7039% | DA: 51.2953%
# Day 6 | MAPE: 4.0231% | DA: 51.2953%
# Day 7 | MAPE: 4.2519% | DA: 51.2953%
# Day 8 | MAPE: 4.4985% | DA: 48.7047%
# Day 9 | MAPE: 4.7384% | DA: 51.2953%
# Day 10 | MAPE: 4.9317% | DA: 51.2953%
# Day 11 | MAPE: 5.1213% | DA: 50.7772%
# Day 12 | MAPE: 5.3040% | DA: 50.2591%
# Day 13 | MAPE: 5.5724% | DA: 50.2591%
# Day 14 | MAPE: 5.9048% | DA: 50.2591%
# Day 15 | MAPE: 6.1586% | DA: 50.7772%
# Day 16 | MAPE: 6.3307% | DA: 51.2953%
# Day 17 | MAPE: 6.4829% | DA: 51.2953%
# Day 18 | MAPE: 6.7093% | DA: 51.2953%
# Day 19 | MAPE: 6.7584% | DA: 50.7772%
# Day 20 | MAPE: 6.9837% | DA: 50.7772%
# Day 21 | MAPE: 7.1702% | DA: 50.7772%
# Day 22 | MAPE: 7.4451% | DA: 50.7772%
# Day 23 | MAPE: 7.6502% | DA: 49.2228%
# Day 24 | MAPE: 7.8159% | DA: 50.7772%
# Day 25 | MAPE: 8.0385% | DA: 50.7772%
# Day 26 | MAPE: 8.1141% | DA: 50.7772%
# Day 27 | MAPE: 8.2541% | DA: 50.2591%
# Day 28 | MAPE: 8.3318% | DA: 49.7409%
# Day 29 | MAPE: 8.5064% | DA: 49.7409%
# Day 30 | MAPE: 8.6956% | DA: 50.2591%
# - Mean Absolute Percentage Error (MAPE): 8.6956%
# - Directional Accuracy (DA): 50.2591%
#
# --- Generating Final LSTM Forecast ---
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# - Forecast for 2025-07-22: $102997.64

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_daily_test, 'close', 30, 'Days', 'Test')
# Out:
# =========================================================
# = Naive Model Evaluation on Test Set (Horizon: 30 Days) =
# =========================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 9.8882%
# - Directional Accuracy (DA): 42.0323%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2025-07-22: $102958.00

# %% [markdown]
# ### LSTM Model Evaluation and Final Forecast (1-Year)

# %%
tf.random.set_seed(42)

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_weekly_valid, 'close', 52, 'Weeks', 'Validation')
# Out:
# ================================================================
# = Naive Model Evaluation on Validation Set (Horizon: 52 Weeks) =
# ================================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 50.6933%
# - Directional Accuracy (DA): 50.0000%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2025-02-09: $48295.00

# %%
FEATURE_COLS = ['open', 'high', 'low', 'close', 'volume']
TARGET_COL = 'close'
INPUT_WINDOW = 52
TARGET_WINDOW = 1
FORECAST_HORIZON = 52

# %%
lstm_metrics, lstm_pred = run_lstm_model(X_btc_weekly_train, X_btc_weekly_valid, X_btc_weekly_test,
                                         FEATURE_COLS, TARGET_COL, FORECAST_HORIZON,
                                         INPUT_WINDOW, TARGET_WINDOW,
                                         'Weeks', 'Validation',
                                         naive_metrics, 'iterative')
# Out:
# Trial 15 Complete [00h 00m 11s]
# val_mae: 0.3718857765197754
#
# Best val_mae So Far: 0.3718857765197754
# Total elapsed time: 00h 15m 33s
#
# LSTM hyperparameter tuning complete:
# - n_conv_layers: 2
# - kernel_size: 5
# - n_rnn_layers: 3
# - use_l2: True
# - dropout_rate: 0.30000000000000004
# - learning_rate: 0.005117045969850107
# - optimizer: adam
# - clipnorm: 1.1
# - filters_0: 96
# - units_0: 96
# - filters_1: 192
# - units_1: 160
# - filters_2: 224
# - units_2: 32
# - l2_rate: 0.005343634220268847
#
# --- Fitting LSTM Model ---
# Epoch 1/100
# 15/15 - 15s - 977ms/step - loss: 5.4017 - mae: 1.0635 - val_loss: 3.1071 - val_mae: 0.4329 - learning_rate: 0.0051
# Epoch 2/100
# 15/15 - 5s - 308ms/step - loss: 2.4607 - mae: 0.8343 - val_loss: 1.3747 - val_mae: 0.4007 - learning_rate: 0.0051
# Epoch 3/100
# 15/15 - 4s - 300ms/step - loss: 1.3164 - mae: 0.7680 - val_loss: 0.7444 - val_mae: 0.3948 - learning_rate: 0.0051
# Epoch 4/100
# 15/15 - 5s - 306ms/step - loss: 0.8550 - mae: 0.7330 - val_loss: 0.4414 - val_mae: 0.3762 - learning_rate: 0.0051
# Epoch 5/100
# 15/15 - 5s - 306ms/step - loss: 0.6531 - mae: 0.7332 - val_loss: 0.3100 - val_mae: 0.3749 - learning_rate: 0.0051
# Epoch 6/100
# 15/15 - 4s - 298ms/step - loss: 0.5439 - mae: 0.7139 - val_loss: 0.2273 - val_mae: 0.3844 - learning_rate: 0.0051
# Epoch 7/100
# 15/15 - 5s - 315ms/step - loss: 0.5104 - mae: 0.7524 - val_loss: 0.1835 - val_mae: 0.3778 - learning_rate: 0.0051
# Epoch 8/100
# 15/15 - 5s - 306ms/step - loss: 0.4286 - mae: 0.6941 - val_loss: 0.1694 - val_mae: 0.3740 - learning_rate: 0.0051
# Epoch 9/100
# 15/15 - 5s - 308ms/step - loss: 0.4299 - mae: 0.7188 - val_loss: 0.1455 - val_mae: 0.3725 - learning_rate: 0.0051
# Epoch 10/100
# 15/15 - 5s - 312ms/step - loss: 0.4068 - mae: 0.7098 - val_loss: 0.1356 - val_mae: 0.3731 - learning_rate: 0.0051
# Epoch 11/100
# 15/15 - 5s - 312ms/step - loss: 0.4010 - mae: 0.7105 - val_loss: 0.1392 - val_mae: 0.3726 - learning_rate: 0.0051
# Epoch 12/100
# 15/15 - 5s - 312ms/step - loss: 0.3740 - mae: 0.6789 - val_loss: 0.1330 - val_mae: 0.3728 - learning_rate: 0.0051
# Epoch 13/100
# 15/15 - 4s - 297ms/step - loss: 0.4307 - mae: 0.7504 - val_loss: 0.1260 - val_mae: 0.3719 - learning_rate: 0.0051
# Epoch 14/100
# 15/15 - 4s - 296ms/step - loss: 0.3774 - mae: 0.7024 - val_loss: 0.1319 - val_mae: 0.3776 - learning_rate: 0.0051
# Epoch 15/100
# 15/15 - 5s - 308ms/step - loss: 0.3682 - mae: 0.6845 - val_loss: 0.1278 - val_mae: 0.3755 - learning_rate: 0.0051
# Epoch 16/100
# 15/15 - 4s - 299ms/step - loss: 0.3826 - mae: 0.7080 - val_loss: 0.1480 - val_mae: 0.4053 - learning_rate: 0.0051
# Epoch 17/100
# 15/15 - 5s - 305ms/step - loss: 0.3929 - mae: 0.7166 - val_loss: 0.1231 - val_mae: 0.3721 - learning_rate: 0.0051
# Epoch 18/100
# 15/15 - 5s - 302ms/step - loss: 0.3936 - mae: 0.7221 - val_loss: 0.1151 - val_mae: 0.3740 - learning_rate: 0.0051
# Epoch 19/100
# 15/15 - 5s - 302ms/step - loss: 0.3837 - mae: 0.7084 - val_loss: 0.1126 - val_mae: 0.3779 - learning_rate: 0.0051
# Epoch 20/100
# 15/15 - 5s - 307ms/step - loss: 0.3816 - mae: 0.7087 - val_loss: 0.1195 - val_mae: 0.3720 - learning_rate: 0.0051
# Epoch 21/100
# 15/15 - 5s - 301ms/step - loss: 0.3740 - mae: 0.6945 - val_loss: 0.1156 - val_mae: 0.3732 - learning_rate: 0.0026
# Epoch 22/100
# 15/15 - 5s - 305ms/step - loss: 0.4185 - mae: 0.7500 - val_loss: 0.1251 - val_mae: 0.3728 - learning_rate: 0.0026
# Epoch 23/100
# 15/15 - 5s - 306ms/step - loss: 0.3718 - mae: 0.6971 - val_loss: 0.1163 - val_mae: 0.3722 - learning_rate: 0.0026
# Epoch 24/100
# 15/15 - 4s - 294ms/step - loss: 0.3815 - mae: 0.7057 - val_loss: 0.1227 - val_mae: 0.3728 - learning_rate: 0.0026
# Epoch 25/100
# 15/15 - 5s - 300ms/step - loss: 0.3838 - mae: 0.7099 - val_loss: 0.1139 - val_mae: 0.3732 - learning_rate: 0.0026
# Epoch 26/100
# 15/15 - 5s - 312ms/step - loss: 0.3786 - mae: 0.7080 - val_loss: 0.1278 - val_mae: 0.3786 - learning_rate: 0.0026
# Epoch 27/100
# 15/15 - 5s - 305ms/step - loss: 0.3837 - mae: 0.7094 - val_loss: 0.1104 - val_mae: 0.3759 - learning_rate: 0.0026
# Epoch 28/100
# 15/15 - 5s - 312ms/step - loss: 0.3863 - mae: 0.7171 - val_loss: 0.1273 - val_mae: 0.3780 - learning_rate: 0.0013
#
# --- Evaluating LSTM Model ---
# Walk-Forward Validation: 100%|██████████| 17/17 [01:43<00:00,  6.09s/it]
# - Mean Absolute Percentage Error (MAPE): 49.8245%
# - Directional Accuracy (DA): 62.5000%
#
# --- Selecting Best LSTM Model ---
# - Naive Model Benchmark: MAPE: 50.6933%, DA: 50.0000%
#
# Found 1 candidate model(s) that beat the naive model:
# - Model: hyperparameters, MAPE: 49.8245%, DA: 62.5000%
#
# --- Best LSTM Model Chosen ---
# - MAPE: 49.8245%
# - DA: 62.5000%
#
# Fitting, evaluating, and predicting LSTM model with the best hyperparameters...
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)               │ (None, None, 96)       │         2,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, None, 192)      │        92,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, None, 96)       │       110,976 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_6           │ (None, None, 96)       │           192 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, None, 160)      │       164,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_7           │ (None, None, 160)      │           320 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_8 (LSTM)                   │ (None, None, 32)       │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_8           │ (None, None, 32)       │            64 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, None, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, None, 1)        │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 395,617 (1.51 MB)
#  Trainable params: 395,617 (1.51 MB)
#  Non-trainable params: 0 (0.00 B)
# --- Fitting LSTM Model ---
# --- Preparing Data for LSTM ---
# Epoch 1/100
# 18/18 - 16s - 891ms/step - loss: 5.0671 - mae: 1.0087 - val_loss: 2.5966 - val_mae: 0.4159 - learning_rate: 0.0051
# Epoch 2/100
# 18/18 - 5s - 295ms/step - loss: 1.9669 - mae: 0.7459 - val_loss: 1.0324 - val_mae: 0.3915 - learning_rate: 0.0051
# Epoch 3/100
# 18/18 - 5s - 291ms/step - loss: 1.0041 - mae: 0.7136 - val_loss: 0.5220 - val_mae: 0.3578 - learning_rate: 0.0051
# Epoch 4/100
# 18/18 - 5s - 299ms/step - loss: 0.6765 - mae: 0.7055 - val_loss: 0.3227 - val_mae: 0.3578 - learning_rate: 0.0051
# Epoch 5/100
# 18/18 - 5s - 293ms/step - loss: 0.5370 - mae: 0.7125 - val_loss: 0.2338 - val_mae: 0.3672 - learning_rate: 0.0051
# Epoch 6/100
# 18/18 - 5s - 300ms/step - loss: 0.4551 - mae: 0.6900 - val_loss: 0.1878 - val_mae: 0.3637 - learning_rate: 0.0051
# Epoch 7/100
# 18/18 - 5s - 296ms/step - loss: 0.4383 - mae: 0.7159 - val_loss: 0.1575 - val_mae: 0.3578 - learning_rate: 0.0051
# Epoch 8/100
# 18/18 - 5s - 297ms/step - loss: 0.3795 - mae: 0.6700 - val_loss: 0.1484 - val_mae: 0.3718 - learning_rate: 0.0051
# Epoch 9/100
# 18/18 - 5s - 299ms/step - loss: 0.4218 - mae: 0.7237 - val_loss: 0.1444 - val_mae: 0.3697 - learning_rate: 0.0051
# Epoch 10/100
# 18/18 - 5s - 293ms/step - loss: 0.3867 - mae: 0.6979 - val_loss: 0.1464 - val_mae: 0.3978 - learning_rate: 0.0051
# Epoch 11/100
# 18/18 - 5s - 293ms/step - loss: 0.3998 - mae: 0.7102 - val_loss: 0.1365 - val_mae: 0.3633 - learning_rate: 0.0026
# Epoch 12/100
# 18/18 - 5s - 288ms/step - loss: 0.3874 - mae: 0.7056 - val_loss: 0.1301 - val_mae: 0.3604 - learning_rate: 0.0026
# Epoch 13/100
# 18/18 - 5s - 297ms/step - loss: 0.3921 - mae: 0.7082 - val_loss: 0.1361 - val_mae: 0.3727 - learning_rate: 0.0026
# Epoch 14/100
# 18/18 - 5s - 292ms/step - loss: 0.3825 - mae: 0.6940 - val_loss: 0.1270 - val_mae: 0.3577 - learning_rate: 0.0026
# Epoch 15/100
# 18/18 - 5s - 298ms/step - loss: 0.3734 - mae: 0.6915 - val_loss: 0.1275 - val_mae: 0.3620 - learning_rate: 0.0026
# Epoch 16/100
# 18/18 - 5s - 294ms/step - loss: 0.3771 - mae: 0.6975 - val_loss: 0.1323 - val_mae: 0.3658 - learning_rate: 0.0026
# Epoch 17/100
# 18/18 - 5s - 293ms/step - loss: 0.3777 - mae: 0.6925 - val_loss: 0.1248 - val_mae: 0.3590 - learning_rate: 0.0026
# Epoch 18/100
# 18/18 - 5s - 299ms/step - loss: 0.3774 - mae: 0.6933 - val_loss: 0.1248 - val_mae: 0.3608 - learning_rate: 0.0013
# Epoch 19/100
# 18/18 - 5s - 293ms/step - loss: 0.3792 - mae: 0.6971 - val_loss: 0.1271 - val_mae: 0.3590 - learning_rate: 0.0013
# Epoch 20/100
# 18/18 - 5s - 297ms/step - loss: 0.3772 - mae: 0.6986 - val_loss: 0.1248 - val_mae: 0.3577 - learning_rate: 0.0013
# Epoch 21/100
# 18/18 - 5s - 295ms/step - loss: 0.3933 - mae: 0.7153 - val_loss: 0.1272 - val_mae: 0.3616 - learning_rate: 0.0013
# Epoch 22/100
# 18/18 - 6s - 311ms/step - loss: 0.3685 - mae: 0.6811 - val_loss: 0.1239 - val_mae: 0.3578 - learning_rate: 0.0013
# Epoch 23/100
# 18/18 - 6s - 306ms/step - loss: 0.3759 - mae: 0.6968 - val_loss: 0.1227 - val_mae: 0.3577 - learning_rate: 0.0013
# Epoch 24/100
# 18/18 - 6s - 308ms/step - loss: 0.3699 - mae: 0.6871 - val_loss: 0.1246 - val_mae: 0.3595 - learning_rate: 0.0013
# Epoch 25/100
# 18/18 - 6s - 325ms/step - loss: 0.3908 - mae: 0.7106 - val_loss: 0.1226 - val_mae: 0.3580 - learning_rate: 6.3963e-04
# Epoch 26/100
# 18/18 - 5s - 302ms/step - loss: 0.3751 - mae: 0.6961 - val_loss: 0.1262 - val_mae: 0.3619 - learning_rate: 6.3963e-04
# Epoch 27/100
# 18/18 - 6s - 316ms/step - loss: 0.3771 - mae: 0.6979 - val_loss: 0.1223 - val_mae: 0.3577 - learning_rate: 6.3963e-04
# Epoch 28/100
# 18/18 - 6s - 306ms/step - loss: 0.3762 - mae: 0.6923 - val_loss: 0.1221 - val_mae: 0.3577 - learning_rate: 6.3963e-04
# Epoch 29/100
# 18/18 - 6s - 314ms/step - loss: 0.3684 - mae: 0.6891 - val_loss: 0.1222 - val_mae: 0.3577 - learning_rate: 6.3963e-04
#
# --- Evaluating LSTM Model ---
# Walk-Forward Validation: 100%|██████████| 18/18 [01:53<00:00,  6.32s/it]
# - Mean Absolute Percentage Error (MAPE): 29.1709%
# - Directional Accuracy (DA): 52.9412%
#
# --- Generating Final LSTM Forecast ---
# - Forecast for 2025-08-13: $104530.32

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_weekly_test, 'close', 52, 'Weeks', 'Test')
# Out:
# ==========================================================
# = Naive Model Evaluation on Test Set (Horizon: 52 Weeks) =
# ==========================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 30.4386%
# - Directional Accuracy (DA): 50.0000%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2026-06-21: $102958.00
