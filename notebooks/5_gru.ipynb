# %% [markdown]
# ### Import, mount, and configure

# %%
import os
import sys
from pathlib import Path

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn
import sklearn
import statsmodels
import tensorflow as tf
import tqdm
from google.colab import drive

# %%
drive.mount('/content/drive')

DRIVE_ROOT = Path('/content/drive/MyDrive')

PROJECT_ROOT = DRIVE_ROOT / 'projects/btc'
PROJECT_DATA_DIR = PROJECT_ROOT / 'data'
PROJECT_CLEANED_DIR = PROJECT_DATA_DIR / 'cleaned'

BTC_CLEANED_CSV_FILENAME = 'btc_274_cleaned.csv'

BTC_CLEANED_FILEPATH = PROJECT_CLEANED_DIR / BTC_CLEANED_CSV_FILENAME
# Out:
# Mounted at /content/drive

# %%
if 'google.colab' in sys.modules:
    # %pip install -q -U keras_tuner

import keras_tuner as kt
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 6.3 MB/s eta 0:00:00

# %%
# %pip install finta
# Out:
# Collecting finta
#   Downloading finta-1.3-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from finta) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from finta) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->finta) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->finta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->finta) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->finta) (1.17.0)
# Downloading finta-1.3-py3-none-any.whl (29 kB)
# Installing collected packages: finta
# Successfully installed finta-1.3

# %%
project_root = os.path.abspath(PROJECT_ROOT)

if project_root not in sys.path:
  sys.path.append(project_root)

print(f'Project root "{project_root}" added to sys.path.')
# Out:
# Project root "/content/drive/MyDrive/projects/btc" added to sys.path.

# %%
from src.analysis import *
from src.data_loader import *
from src.data_splitter import *
from src.model import *
from src.preprocessing import *
from src.utils import *
from src.visualization import *

# %% [markdown]
# ### Load the cleaned dataset, and resample it

# %%
# A missing date(2025-03-15) exists in the test dataset.
X_btc_cleaned = load_btc_dataset(BTC_CLEANED_FILEPATH, 'date', True)
btc_resampled = resample_btc_data(X_btc_cleaned)
# Out:
# Loading dataset from: btc_274_cleaned.csv...
# Dataset loaded successfully.
#
# --- Resampling BTC Data to Multiple Timeframes ---
# Resampling to hourly frequency...
# Resampling to daily frequency...
# Resampling to weekly frequency...
# Resampling to monthly frequency...
# --- BTC Data Resampling Complete ---

# %% [markdown]
# ### Split the resampled datasets into a training set, a validation set, and a test set of respective timeframe, and take returns

# %%
for X_btc_resampled in btc_resampled.values():
    X_btc_resampled = calculate_returns(X_btc_resampled, 'close')

# %%
X_btc_daily_train, X_btc_daily_valid, X_btc_daily_test = split_btc_dataset(btc_resampled['daily'], 'Day')
X_btc_weekly_train, X_btc_weekly_valid, X_btc_weekly_test = split_btc_dataset(btc_resampled['weekly'], 'Week')
# Out:
# --- Splitting BTC Dataset to Training, Validation, and Test Set (Day) ---
# --- BTC Dataset Splitting Complete ---
#
# --- Splitting BTC Dataset to Training, Validation, and Test Set (Week) ---
# --- BTC Dataset Splitting Complete ---

# %% [markdown]
# ### Run the ADF test on datasets at multiple frequencies to verify stationarity and seasonality

# %%
run_adf_test(X_btc_daily_train, 'returns_close', 'BTC Daily Closing Returns')
run_adf_test(X_btc_weekly_train, 'returns_close', 'BTC Weekly Closing Returns')
# Out:
# =======================================
# = ADF Test: BTC Daily Closing Returns =
# =======================================
# ADF Statistics: -10.1710
# p-value: 0.0000
# Critical Values:
# 	1%:-3.4320
# 	5%:-2.8623
# 	10%:-2.5672
# Conclusion: The p-value is less than or equal to 0.05. The data is likely stationary and seasonal.
#
# ========================================
# = ADF Test: BTC Weekly Closing Returns =
# ========================================
# ADF Statistics: -11.0168
# p-value: 0.0000
# Critical Values:
# 	1%:-3.4421
# 	5%:-2.8667
# 	10%:-2.5695
# Conclusion: The p-value is less than or equal to 0.05. The data is likely stationary and seasonal.

# %% [markdown]
# ### GRU Model Evaluation and Final Forecast (1-Month)

# %%
tf.random.set_seed(42)

# %%
FEATURE_COLS = ['open', 'high', 'low', 'close', 'volume']
TARGET_COL = 'close'
INPUT_WINDOW = 270
TARGET_WINDOW = 30
FORECAST_HORIZON = 30

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_daily_valid, 'close', 30, 'Days', 'Validation')
# Out:
# ===============================================================
# = Naive Model Evaluation on Validation Set (Horizon: 30 Days) =
# ===============================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 10.5643%
# - Directional Accuracy (DA): 54.8611%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2024-03-15: $51475.00

# %%
gru_metrics, gru_pred = run_gru_model(X_btc_daily_train, X_btc_daily_valid, X_btc_daily_test,
                                      FEATURE_COLS, TARGET_COL, FORECAST_HORIZON,
                                      INPUT_WINDOW, TARGET_WINDOW,
                                      'Days', 'Validation',
                                      naive_metrics, 'direct')
# Out:
# Trial 15 Complete [00h 01m 29s]
# val_mae: 0.3603944778442383
#
# Best val_mae So Far: 0.3602541983127594
# Total elapsed time: 05h 43m 35s
#
# LSTM hyperparameter tuning complete:
# - n_conv_layers: 2
# - kernel_size: 5
# - n_rnn_layers: 1
# - use_l2: True
# - dropout_rate: 0.0
# - learning_rate: 0.005218086982564764
# - optimizer: nadam
# - clipnorm: 0.8
# - filters_0: 192
# - units_0: 192
# - filters_1: 64
# - units_1: 224
# - filters_2: 96
# - units_2: 32
# - l2_rate: 0.0025124079357885637
#
# --- Fitting GRU Model ---
# Epoch 1/100
# 113/113 - 5s - 45ms/step - loss: 0.7692 - mae: 0.6642 - val_loss: 0.1692 - val_mae: 0.3678 - learning_rate: 0.0052
# Epoch 2/100
# 113/113 - 2s - 16ms/step - loss: 0.3412 - mae: 0.6269 - val_loss: 0.1345 - val_mae: 0.3607 - learning_rate: 0.0052
# Epoch 3/100
# 113/113 - 2s - 16ms/step - loss: 0.3331 - mae: 0.6288 - val_loss: 0.1342 - val_mae: 0.3622 - learning_rate: 0.0052
# Epoch 4/100
# 113/113 - 2s - 16ms/step - loss: 0.3322 - mae: 0.6286 - val_loss: 0.1347 - val_mae: 0.3640 - learning_rate: 0.0052
# Epoch 5/100
# 113/113 - 2s - 16ms/step - loss: 0.3322 - mae: 0.6283 - val_loss: 0.1354 - val_mae: 0.3658 - learning_rate: 0.0052
# Epoch 6/100
# 113/113 - 2s - 16ms/step - loss: 0.3326 - mae: 0.6289 - val_loss: 0.1351 - val_mae: 0.3710 - learning_rate: 0.0052
# Epoch 7/100
# 113/113 - 2s - 16ms/step - loss: 0.3318 - mae: 0.6279 - val_loss: 0.1330 - val_mae: 0.3617 - learning_rate: 0.0052
# Epoch 8/100
# 113/113 - 2s - 16ms/step - loss: 0.3329 - mae: 0.6298 - val_loss: 0.1329 - val_mae: 0.3604 - learning_rate: 0.0052
# Epoch 9/100
# 113/113 - 2s - 16ms/step - loss: 0.3322 - mae: 0.6286 - val_loss: 0.1329 - val_mae: 0.3603 - learning_rate: 0.0052
# Epoch 10/100
# 113/113 - 2s - 16ms/step - loss: 0.3320 - mae: 0.6283 - val_loss: 0.1328 - val_mae: 0.3603 - learning_rate: 0.0052
# Epoch 11/100
# 113/113 - 2s - 16ms/step - loss: 0.3319 - mae: 0.6281 - val_loss: 0.1329 - val_mae: 0.3610 - learning_rate: 0.0052
# Epoch 12/100
# 113/113 - 2s - 16ms/step - loss: 0.3323 - mae: 0.6287 - val_loss: 0.1328 - val_mae: 0.3604 - learning_rate: 0.0052
# Epoch 13/100
# 113/113 - 2s - 16ms/step - loss: 0.3323 - mae: 0.6285 - val_loss: 0.1328 - val_mae: 0.3606 - learning_rate: 0.0052
# Epoch 14/100
# 113/113 - 2s - 16ms/step - loss: 0.3317 - mae: 0.6277 - val_loss: 0.1333 - val_mae: 0.3633 - learning_rate: 0.0052
# Epoch 15/100
# 113/113 - 2s - 16ms/step - loss: 0.3320 - mae: 0.6279 - val_loss: 0.1344 - val_mae: 0.3633 - learning_rate: 0.0052
# Epoch 16/100
# 113/113 - 2s - 16ms/step - loss: 0.3322 - mae: 0.6279 - val_loss: 0.1329 - val_mae: 0.3602 - learning_rate: 0.0026
# Epoch 17/100
# 113/113 - 2s - 16ms/step - loss: 0.3312 - mae: 0.6268 - val_loss: 0.1329 - val_mae: 0.3602 - learning_rate: 0.0026
# Epoch 18/100
# 113/113 - 2s - 16ms/step - loss: 0.3329 - mae: 0.6289 - val_loss: 0.1328 - val_mae: 0.3603 - learning_rate: 0.0026
# Epoch 19/100
# 113/113 - 2s - 16ms/step - loss: 0.3305 - mae: 0.6258 - val_loss: 0.1337 - val_mae: 0.3618 - learning_rate: 0.0026
# Epoch 20/100
# 113/113 - 2s - 16ms/step - loss: 0.3316 - mae: 0.6273 - val_loss: 0.1330 - val_mae: 0.3604 - learning_rate: 0.0026
# Epoch 21/100
# 113/113 - 2s - 16ms/step - loss: 0.3329 - mae: 0.6289 - val_loss: 0.1330 - val_mae: 0.3603 - learning_rate: 0.0026
# Epoch 22/100
# 113/113 - 2s - 16ms/step - loss: 0.3317 - mae: 0.6275 - val_loss: 0.1331 - val_mae: 0.3605 - learning_rate: 0.0026
# Epoch 23/100
# 113/113 - 2s - 16ms/step - loss: 0.3311 - mae: 0.6266 - val_loss: 0.1329 - val_mae: 0.3603 - learning_rate: 0.0026
# Epoch 24/100
# 113/113 - 2s - 16ms/step - loss: 0.3321 - mae: 0.6278 - val_loss: 0.1328 - val_mae: 0.3605 - learning_rate: 0.0013
# Epoch 25/100
# 113/113 - 2s - 16ms/step - loss: 0.3317 - mae: 0.6274 - val_loss: 0.1329 - val_mae: 0.3615 - learning_rate: 0.0013
# Epoch 26/100
# 113/113 - 2s - 16ms/step - loss: 0.3319 - mae: 0.6276 - val_loss: 0.1331 - val_mae: 0.3622 - learning_rate: 0.0013
# Epoch 27/100
# 113/113 - 2s - 16ms/step - loss: 0.3315 - mae: 0.6272 - val_loss: 0.1334 - val_mae: 0.3635 - learning_rate: 0.0013
# Epoch 28/100
# 113/113 - 2s - 16ms/step - loss: 0.3315 - mae: 0.6272 - val_loss: 0.1330 - val_mae: 0.3620 - learning_rate: 0.0013
# Epoch 29/100
# 113/113 - 2s - 16ms/step - loss: 0.3315 - mae: 0.6271 - val_loss: 0.1332 - val_mae: 0.3627 - learning_rate: 0.0013
# Epoch 30/100
# 113/113 - 2s - 16ms/step - loss: 0.3317 - mae: 0.6273 - val_loss: 0.1330 - val_mae: 0.3619 - learning_rate: 0.0013
# Epoch 31/100
# 113/113 - 2s - 16ms/step - loss: 0.3317 - mae: 0.6275 - val_loss: 0.1330 - val_mae: 0.3619 - learning_rate: 6.5226e-04
# Epoch 32/100
# 113/113 - 2s - 16ms/step - loss: 0.3320 - mae: 0.6278 - val_loss: 0.1332 - val_mae: 0.3627 - learning_rate: 6.5226e-04
#
# --- Evaluating GRU Model ---
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Day 1 | MAPE: 1.4238% | DA: 54.1667%
# Day 2 | MAPE: 1.9527% | DA: 53.6458%
# Day 3 | MAPE: 2.4436% | DA: 53.1250%
# Day 4 | MAPE: 2.8743% | DA: 53.6458%
# Day 5 | MAPE: 3.3123% | DA: 53.6458%
# Day 6 | MAPE: 3.6293% | DA: 53.6458%
# Day 7 | MAPE: 3.9874% | DA: 53.6458%
# Day 8 | MAPE: 4.2765% | DA: 53.1250%
# Day 9 | MAPE: 4.5863% | DA: 53.6458%
# Day 10 | MAPE: 4.8540% | DA: 54.1667%
# Day 11 | MAPE: 5.0935% | DA: 54.6875%
# Day 12 | MAPE: 5.3139% | DA: 54.1667%
# Day 13 | MAPE: 5.4697% | DA: 54.6875%
# Day 14 | MAPE: 5.6611% | DA: 54.6875%
# Day 15 | MAPE: 5.8779% | DA: 55.2083%
# Day 16 | MAPE: 6.2133% | DA: 55.2083%
# Day 17 | MAPE: 6.5039% | DA: 55.2083%
# Day 18 | MAPE: 6.7825% | DA: 55.2083%
# Day 19 | MAPE: 7.0927% | DA: 55.2083%
# Day 20 | MAPE: 7.4001% | DA: 55.2083%
# Day 21 | MAPE: 7.7351% | DA: 54.6875%
# Day 22 | MAPE: 8.0188% | DA: 54.6875%
# Day 23 | MAPE: 8.3519% | DA: 55.2083%
# Day 24 | MAPE: 8.6717% | DA: 55.7292%
# Day 25 | MAPE: 8.9630% | DA: 55.7292%
# Day 26 | MAPE: 9.2817% | DA: 55.7292%
# Day 27 | MAPE: 9.5839% | DA: 55.7292%
# Day 28 | MAPE: 9.8638% | DA: 56.2500%
# Day 29 | MAPE: 10.0616% | DA: 55.7292%
# Day 30 | MAPE: 10.2933% | DA: 55.7292%
# - Mean Absolute Percentage Error (MAPE): 10.2933%
# - Directional Accuracy (DA): 55.7292%
#
# --- Selecting Best GRU Model ---
# - Naive Model Benchmark: MAPE: 10.5643%, DA: 54.8611%
#
# Found 1 candidate model(s) that beat the naive model:
# - Model: hyperparameters, MAPE: 10.2933%, DA: 55.7292%
#
# --- Best GRU Model Chosen ---
# - MAPE: 10.2933%
# - DA: 55.7292%
#
# Fitting, evaluating, and predicting GRU model with the best hyperparameters...
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)               │ (None, None, 192)      │         4,992 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, None, 64)       │        61,504 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, None, 192)      │       148,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_4           │ (None, None, 192)      │           384 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, None, 30)       │         5,790 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 221,278 (864.37 KB)
#  Trainable params: 221,278 (864.37 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Fitting GRU Model ---
# --- Preparing Data for GRU ---
# Epoch 1/100
# 128/128 - 6s - 44ms/step - loss: 0.7162 - mae: 0.6584 - val_loss: 0.1982 - val_mae: 0.4526 - learning_rate: 0.0052
# Epoch 2/100
# 128/128 - 2s - 16ms/step - loss: 0.3386 - mae: 0.6290 - val_loss: 0.1888 - val_mae: 0.4734 - learning_rate: 0.0052
# Epoch 3/100
# 128/128 - 2s - 16ms/step - loss: 0.3335 - mae: 0.6290 - val_loss: 0.1810 - val_mae: 0.4591 - learning_rate: 0.0052
# Epoch 4/100
# 128/128 - 2s - 16ms/step - loss: 0.3332 - mae: 0.6292 - val_loss: 0.1780 - val_mae: 0.4545 - learning_rate: 0.0052
# Epoch 5/100
# 128/128 - 2s - 16ms/step - loss: 0.3335 - mae: 0.6294 - val_loss: 0.1861 - val_mae: 0.4705 - learning_rate: 0.0052
# Epoch 6/100
# 128/128 - 2s - 16ms/step - loss: 0.3337 - mae: 0.6302 - val_loss: 0.1791 - val_mae: 0.4535 - learning_rate: 0.0052
# Epoch 7/100
# 128/128 - 2s - 16ms/step - loss: 0.3328 - mae: 0.6284 - val_loss: 0.1779 - val_mae: 0.4527 - learning_rate: 0.0052
# Epoch 8/100
# 128/128 - 2s - 16ms/step - loss: 0.3339 - mae: 0.6303 - val_loss: 0.1775 - val_mae: 0.4522 - learning_rate: 0.0052
# Epoch 9/100
# 128/128 - 2s - 16ms/step - loss: 0.3330 - mae: 0.6286 - val_loss: 0.1776 - val_mae: 0.4524 - learning_rate: 0.0052
# Epoch 10/100
# 128/128 - 2s - 16ms/step - loss: 0.3337 - mae: 0.6299 - val_loss: 0.1777 - val_mae: 0.4509 - learning_rate: 0.0052
# Epoch 11/100
# 128/128 - 2s - 16ms/step - loss: 0.3330 - mae: 0.6286 - val_loss: 0.1775 - val_mae: 0.4519 - learning_rate: 0.0052
# Epoch 12/100
# 128/128 - 2s - 16ms/step - loss: 0.3326 - mae: 0.6280 - val_loss: 0.1788 - val_mae: 0.4518 - learning_rate: 0.0052
# Epoch 13/100
# 128/128 - 2s - 16ms/step - loss: 0.3334 - mae: 0.6292 - val_loss: 0.1777 - val_mae: 0.4509 - learning_rate: 0.0052
# Epoch 14/100
# 128/128 - 2s - 16ms/step - loss: 0.3327 - mae: 0.6282 - val_loss: 0.1779 - val_mae: 0.4508 - learning_rate: 0.0052
# Epoch 15/100
# 128/128 - 2s - 16ms/step - loss: 0.3331 - mae: 0.6287 - val_loss: 0.1775 - val_mae: 0.4520 - learning_rate: 0.0052
# 128/128 - 2s - 16ms/step - loss: 0.3323 - mae: 0.6273 - val_loss: 0.1775 - val_mae: 0.4520 - learning_rate: 6.5226e-04
# Epoch 35/100
# 128/128 - 2s - 16ms/step - loss: 0.3321 - mae: 0.6271 - val_loss: 0.1777 - val_mae: 0.4535 - learning_rate: 6.5226e-04
# Epoch 36/100
# 128/128 - 2s - 16ms/step - loss: 0.3319 - mae: 0.6268 - val_loss: 0.1777 - val_mae: 0.4534 - learning_rate: 6.5226e-04
# Epoch 37/100
# 128/128 - 2s - 16ms/step - loss: 0.3320 - mae: 0.6269 - val_loss: 0.1781 - val_mae: 0.4555 - learning_rate: 6.5226e-04
# Epoch 38/100
# 128/128 - 2s - 16ms/step - loss: 0.3321 - mae: 0.6272 - val_loss: 0.1780 - val_mae: 0.4548 - learning_rate: 6.5226e-04
# Epoch 39/100
# 128/128 - 2s - 17ms/step - loss: 0.3315 - mae: 0.6263 - val_loss: 0.1791 - val_mae: 0.4593 - learning_rate: 6.5226e-04
# Epoch 40/100
# 128/128 - 2s - 16ms/step - loss: 0.3321 - mae: 0.6272 - val_loss: 0.1795 - val_mae: 0.4607 - learning_rate: 6.5226e-04
# Epoch 41/100
# 128/128 - 2s - 17ms/step - loss: 0.3321 - mae: 0.6274 - val_loss: 0.1807 - val_mae: 0.4643 - learning_rate: 3.2613e-04
#
# --- Evaluating GRU Model ---
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Day 1 | MAPE: 1.8674% | DA: 51.2953%
# Day 2 | MAPE: 2.5079% | DA: 51.8135%
# Day 3 | MAPE: 3.0125% | DA: 51.8135%
# Day 4 | MAPE: 3.3483% | DA: 51.8135%
# Day 5 | MAPE: 3.7026% | DA: 51.2953%
# Day 6 | MAPE: 4.0218% | DA: 51.2953%
# Day 7 | MAPE: 4.2510% | DA: 51.2953%
# Day 8 | MAPE: 4.4948% | DA: 51.2953%
# Day 9 | MAPE: 4.7390% | DA: 51.2953%
# Day 10 | MAPE: 4.9312% | DA: 51.2953%
# Day 11 | MAPE: 5.1215% | DA: 50.7772%
# Day 12 | MAPE: 5.3036% | DA: 50.2591%
# Day 13 | MAPE: 5.5728% | DA: 50.2591%
# Day 14 | MAPE: 5.9062% | DA: 50.2591%
# Day 15 | MAPE: 6.1619% | DA: 50.7772%
# Day 16 | MAPE: 6.3318% | DA: 51.2953%
# Day 17 | MAPE: 6.4819% | DA: 51.2953%
# Day 18 | MAPE: 6.7086% | DA: 51.2953%
# Day 19 | MAPE: 6.7583% | DA: 50.7772%
# Day 20 | MAPE: 6.9832% | DA: 50.7772%
# Day 21 | MAPE: 7.1690% | DA: 50.7772%
# Day 22 | MAPE: 7.4452% | DA: 49.2228%
# Day 23 | MAPE: 7.6500% | DA: 50.7772%
# Day 24 | MAPE: 7.8163% | DA: 50.7772%
# Day 25 | MAPE: 8.0385% | DA: 50.7772%
# Day 26 | MAPE: 8.1140% | DA: 50.7772%
# Day 27 | MAPE: 8.2540% | DA: 50.2591%
# Day 28 | MAPE: 8.3314% | DA: 49.7409%
# Day 29 | MAPE: 8.5056% | DA: 49.7409%
# Day 30 | MAPE: 8.6961% | DA: 50.2591%
# - Mean Absolute Percentage Error (MAPE): 8.6961%
# - Directional Accuracy (DA): 50.2591%
#
# --- Generating Final GRU Forecast ---
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# - Forecast for 2025-07-22: $102970.13

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_daily_test, 'close', 30, 'Days', 'Validation')
# Out:
# ===============================================================
# = Naive Model Evaluation on Validation Set (Horizon: 30 Days) =
# ===============================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 9.8882%
# - Directional Accuracy (DA): 42.0323%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2025-07-22: $102958.00

# %% [markdown]
# ### GRU Model Evaluation and Final Forecast (1-Year)

# %%
tf.random.set_seed(42)

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_weekly_valid, 'close', 52, 'Weeks', 'Validation')
# Out:
# ================================================================
# = Naive Model Evaluation on Validation Set (Horizon: 52 Weeks) =
# ================================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 50.6933%
# - Directional Accuracy (DA): 50.0000%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2025-02-09: $48295.00

# %%
FEATURE_COLS = ['open', 'high', 'low', 'close', 'volume']
TARGET_COL = 'close'
INPUT_WINDOW = 52
TARGET_WINDOW = 1
FORECAST_HORIZON = 52

# %%
gru_metrics, gru_pred = run_gru_model(X_btc_weekly_train, X_btc_weekly_valid, X_btc_weekly_test,
                                      FEATURE_COLS, TARGET_COL, FORECAST_HORIZON,
                                      INPUT_WINDOW, TARGET_WINDOW,
                                      'Days', 'Validation',
                                      naive_metrics, 'iterative')
# Out:
# Trial 15 Complete [00h 00m 11s]
# val_mae: 0.3719090521335602
#
# Best val_mae So Far: 0.3718875050544739
# Total elapsed time: 00h 16m 00s
#
# LSTM hyperparameter tuning complete:
# - n_conv_layers: 2
# - kernel_size: 3
# - n_rnn_layers: 2
# - use_l2: False
# - dropout_rate: 0.0
# - learning_rate: 0.0033710341251377745
# - optimizer: adam
# - clipnorm: 0.8
# - filters_0: 128
# - units_0: 32
# - filters_1: 160
# - units_1: 96
# - filters_2: 160
# - units_2: 128
#
# --- Fitting GRU Model ---
# Epoch 1/100
# 15/15 - 4s - 280ms/step - loss: 0.8131 - mae: 1.1920 - val_loss: 0.1082 - val_mae: 0.3770 - learning_rate: 0.0034
# Epoch 2/100
# 15/15 - 0s - 15ms/step - loss: 0.4375 - mae: 0.7872 - val_loss: 0.2841 - val_mae: 0.6246 - learning_rate: 0.0034
# Epoch 3/100
# 15/15 - 0s - 14ms/step - loss: 0.4374 - mae: 0.7945 - val_loss: 0.1871 - val_mae: 0.4676 - learning_rate: 0.0034
# Epoch 4/100
# 15/15 - 0s - 15ms/step - loss: 0.3647 - mae: 0.6965 - val_loss: 0.1724 - val_mae: 0.4467 - learning_rate: 0.0034
# Epoch 5/100
# 15/15 - 0s - 15ms/step - loss: 0.4114 - mae: 0.7514 - val_loss: 0.1094 - val_mae: 0.3992 - learning_rate: 0.0034
# Epoch 6/100
# Epoch 25/100
# 15/15 - 0s - 15ms/step - loss: 0.3569 - mae: 0.6932 - val_loss: 0.1279 - val_mae: 0.3824 - learning_rate: 0.0017
# Epoch 26/100
# 15/15 - 0s - 14ms/step - loss: 0.4199 - mae: 0.7543 - val_loss: 0.1310 - val_mae: 0.3876 - learning_rate: 0.0017
# Epoch 27/100
# 15/15 - 0s - 14ms/step - loss: 0.3764 - mae: 0.7084 - val_loss: 0.1062 - val_mae: 0.3792 - learning_rate: 8.4276e-04
#
# --- Evaluating GRU Model ---
# Walk-Forward Validation: 100%|██████████| 17/17 [01:00<00:00,  3.55s/it]
# - Mean Absolute Percentage Error (MAPE): 49.4592%
# - Directional Accuracy (DA): 75.0000%
#
# --- Selecting Best GRU Model ---
# - Naive Model Benchmark: MAPE: 50.6933%, DA: 50.0000%
#
# Found 1 candidate model(s) that beat the naive model:
# - Model: hyperparameters, MAPE: 49.4592%, DA: 75.0000%
#
# --- Best GRU Model Chosen ---
# - MAPE: 49.4592%
# - DA: 75.0000%
#
# Fitting, evaluating, and predicting GRU model with the best hyperparameters...
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_5 (Conv1D)               │ (None, None, 128)      │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_6 (Conv1D)               │ (None, None, 160)      │        61,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_2 (GRU)                     │ (None, None, 32)       │        18,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_5           │ (None, None, 32)       │            64 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_3 (GRU)                     │ (None, None, 96)       │        37,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ layer_normalization_6           │ (None, None, 96)       │           192 │
# │ (LayerNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, None, 1)        │            97 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,065 (469.00 KB)
#  Trainable params: 120,065 (469.00 KB)
#  Non-trainable params: 0 (0.00 B)
# --- Fitting GRU Model ---
# --- Preparing Data for GRU ---
# Epoch 1/100
# 18/18 - 4s - 243ms/step - loss: 0.7237 - mae: 1.0855 - val_loss: 0.1999 - val_mae: 0.5326 - learning_rate: 0.0034
# Epoch 2/100
# 18/18 - 0s - 16ms/step - loss: 0.4030 - mae: 0.7340 - val_loss: 0.1211 - val_mae: 0.3599 - learning_rate: 0.0034
# Epoch 3/100
# 18/18 - 0s - 15ms/step - loss: 0.3766 - mae: 0.7064 - val_loss: 0.1240 - val_mae: 0.3657 - learning_rate: 0.0034
# Epoch 4/100
# 18/18 - 0s - 13ms/step - loss: 0.3928 - mae: 0.7308 - val_loss: 0.2004 - val_mae: 0.5264 - learning_rate: 0.0034
# Epoch 5/100
# 18/18 - 0s - 13ms/step - loss: 0.4012 - mae: 0.7352 - val_loss: 0.1201 - val_mae: 0.3623 - learning_rate: 0.0034
# Epoch 6/100
# 18/18 - 0s - 15ms/step - loss: 0.3842 - mae: 0.7211 - val_loss: 0.1223 - val_mae: 0.3623 - learning_rate: 0.0034
# Epoch 7/100
# 18/18 - 0s - 15ms/step - loss: 0.4264 - mae: 0.7726 - val_loss: 0.1898 - val_mae: 0.5180 - learning_rate: 0.0034
# Epoch 8/100
# 18/18 - 0s - 14ms/step - loss: 0.3737 - mae: 0.7144 - val_loss: 0.1987 - val_mae: 0.5233 - learning_rate: 0.0034
# Epoch 9/100
# 18/18 - 0s - 14ms/step - loss: 0.4348 - mae: 0.7869 - val_loss: 0.1813 - val_mae: 0.5028 - learning_rate: 0.0034
# Epoch 10/100
# 18/18 - 0s - 13ms/step - loss: 0.3725 - mae: 0.6936 - val_loss: 0.1182 - val_mae: 0.3577 - learning_rate: 4.2138e-04
# Epoch 29/100
# 18/18 - 0s - 13ms/step - loss: 0.3664 - mae: 0.6917 - val_loss: 0.1203 - val_mae: 0.3585 - learning_rate: 4.2138e-04
# Epoch 30/100
# 18/18 - 0s - 14ms/step - loss: 0.3689 - mae: 0.6890 - val_loss: 0.1189 - val_mae: 0.3577 - learning_rate: 4.2138e-04
# Epoch 31/100
# 18/18 - 0s - 15ms/step - loss: 0.3591 - mae: 0.6854 - val_loss: 0.1185 - val_mae: 0.3577 - learning_rate: 4.2138e-04
# Epoch 32/100
# 18/18 - 0s - 15ms/step - loss: 0.3910 - mae: 0.7161 - val_loss: 0.1196 - val_mae: 0.3578 - learning_rate: 4.2138e-04
# Epoch 33/100
# 18/18 - 0s - 14ms/step - loss: 0.3558 - mae: 0.6739 - val_loss: 0.1207 - val_mae: 0.3590 - learning_rate: 2.1069e-04
# Epoch 34/100
# 18/18 - 0s - 13ms/step - loss: 0.3812 - mae: 0.7056 - val_loss: 0.1193 - val_mae: 0.3577 - learning_rate: 2.1069e-04
# Epoch 35/100
# 18/18 - 0s - 14ms/step - loss: 0.3547 - mae: 0.6763 - val_loss: 0.1190 - val_mae: 0.3577 - learning_rate: 2.1069e-04
# Epoch 36/100
# 18/18 - 0s - 15ms/step - loss: 0.3981 - mae: 0.7240 - val_loss: 0.1200 - val_mae: 0.3581 - learning_rate: 2.1069e-04
# Epoch 37/100
# 18/18 - 0s - 15ms/step - loss: 0.3604 - mae: 0.6823 - val_loss: 0.1181 - val_mae: 0.3577 - learning_rate: 2.1069e-04
# Epoch 38/100
# 18/18 - 0s - 15ms/step - loss: 0.3626 - mae: 0.6839 - val_loss: 0.1215 - val_mae: 0.3605 - learning_rate: 2.1069e-04
# Epoch 39/100
# 18/18 - 0s - 13ms/step - loss: 0.3685 - mae: 0.6952 - val_loss: 0.1185 - val_mae: 0.3577 - learning_rate: 2.1069e-04
# Epoch 40/100
# 18/18 - 0s - 13ms/step - loss: 0.3964 - mae: 0.7213 - val_loss: 0.1186 - val_mae: 0.3577 - learning_rate: 1.0534e-04
# Epoch 41/100
# 18/18 - 0s - 16ms/step - loss: 0.3545 - mae: 0.6709 - val_loss: 0.1195 - val_mae: 0.3578 - learning_rate: 1.0534e-04
#
# --- Evaluating GRU Model ---
# Walk-Forward Validation: 100%|██████████| 18/18 [01:04<00:00,  3.60s/it]
# - Mean Absolute Percentage Error (MAPE): 29.3332%
# - Directional Accuracy (DA): 47.0588%
#
# --- Generating Final GRU Forecast ---
# - Forecast for 2025-08-13: $104171.10

# %%
naive_metrics, naive_pred = run_naive_model(X_btc_weekly_test, 'close', 52, 'Weeks', 'Test')
# Out:
# ==========================================================
# = Naive Model Evaluation on Test Set (Horizon: 52 Weeks) =
# ==========================================================
# --- Skipping Naive Model Fitting ---
#
# --- Evaluating Naive Model ---
# - Mean Absolute Percentage Error (MAPE): 30.4386%
# - Directional Accuracy (DA): 50.0000%
#
# --- Generating Final Naive Forecast ---
# - Forecast for 2026-06-21: $102958.00
